# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt
from utilities import *

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# ### Solution du système Van der Pol dans le cas où on ne rajoute pas de perturbation x(t)²-1

# %%
lamb, mu = 1, 1

tt = np.linspace(0,10,200)

x = lambda t: lamb*np.cos(t) + mu*np.sin(t)
y = lambda t: -lamb*np.sin(t) + mu*np.cos(t)

fig = plt.figure(figsize=(6,6))

ax = fig.add_subplot(1,1,1)

ax.plot(x(tt),y(tt));
ax.set_xlabel("x(t)")
ax.set_ylabel("y(t)")
# Out:
# Text(0, 0.5, 'y(t)')

# %% [markdown]
# On trouve une solution cyclique : c'est pour cela qu'on rajoute une perturbation pour ne pas être dans ce cas

# %% [markdown]
# ### Solution du système Van der Pol

# %%
xy0 = [(-2.75,-4),(3,3),(0.1,0.1)]
for xy in xy0:
    x0 = xy[0]
    y0 = xy[1] 

    trace_courbes(x0,y0,1,20)

# %%
xy0 = [(-3,-4),(-2,-3)]
trace_courbes2(xy0,1,20)

# %% [markdown]
# ### Calcul de la période

# %%
periode((-3, 4), 100)
# Out:
# 1.9
